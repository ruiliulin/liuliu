# %% [markdown]
# # 一.索引对象Index

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Series和DataFrame中的索引都是Index对象

# %%
ps1 = pd.Series(np.arange(5), index=['a', 'b', 'c', 'd', 'e'])
print(ps1)
print(type(ps1.index))
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int64
# <class 'pandas.core.indexes.base.Index'>

# %%
pd1 = pd.DataFrame(np.arange(9).reshape(3,3), index=['a', 'b', 'c'], columns=['A', 'B', 'C'])
print(type(pd1.index))
pd1
# Out:
# <class 'pandas.core.indexes.base.Index'>
#    A  B  C
# a  0  1  2
# b  3  4  5
# c  6  7  8

# %% [markdown]
# ## 2. 索引对象不可变，保证了数据的安全

# %%
#ps.index[0] = 2 # 会报错

# %%
#pd1.index[1] = '2' # 会报错

# %% [markdown]
# ## 3. 常见的Index种类
# - Index，索引
# - Int64Index，整数索引
# - MultiIndex，层级索引
# - DatetimeIndex，时间戳类型

# %% [markdown]
# # 二.索引的 一些基本操作
# - 重新索引
# - 增
# - 删
# - 改
# - 查

# %% [markdown]
# ## 1. 重新索引

# %%
# reindex 创建一个符合新索引的新对象
ps2 = ps1.reindex(['a', 'b', 'c', 'd', 'e', 'f'])
ps2
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# f    NaN
# dtype: float64

# %%
# 行索引重建
pd2 = pd1.reindex(['a', 'b', 'c', 'd'])
pd2
# Out:
#      A    B    C
# a  0.0  1.0  2.0
# b  3.0  4.0  5.0
# c  6.0  7.0  8.0
# d  NaN  NaN  NaN

# %%
# 列索引重建
pd3 = pd1.reindex(columns=['C', 'B', 'A'])
pd3
# Out:
#    C  B  A
# a  2  1  0
# b  5  4  3
# c  8  7  6

# %% [markdown]
# ## 增

# %%
ps1
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
ps1['g'] = 9
ps1
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# g    9
# dtype: int64

# %%
# append 可以不改变原有的表格数据
s1 = pd.Series({'f':99})
ps3 = ps1.append(s1)
ps3
# Out:
# a     0
# b     1
# c     2
# d     3
# e     4
# g     9
# f    99
# dtype: int64

# %%
pd1
# Out:
#    A  B  C
# a  0  1  2
# b  3  4  5
# c  6  7  8

# %%
# 末尾增加列
pd1[4] = [10, 11, 12]
pd1
# Out:
#    A  B  C   4
# a  0  1  2  10
# b  3  4  5  11
# c  6  7  8  12

# %%
# 插入增加列
pd1.insert(0, 'E', [7,7,7])
pd1
# Out:
#    E  A  B  C   4
# a  7  0  1  2  10
# b  7  3  4  5  11
# c  7  6  7  8  12

# %%
# 增加行
# 使用高级索引中的标签索引 loc
pd1.loc['d'] = [0,0,0,0,0]
pd1
# Out:
#    E  A  B  C   4
# a  7  0  1  2  10
# b  7  3  4  5  11
# c  7  6  7  8  12
# d  0  0  0  0   0

# %%
# 使用append
row = {'E':6, 'A':6, 'B':6, 'C':6, 4:6}
pd3 = pd1.append(row, ignore_index=True)
pd3
# Out:
#    E  A  B  C   4
# 0  7  0  1  2  10
# 1  7  3  4  5  11
# 2  7  6  7  8  12
# 3  0  0  0  0   0
# 4  6  6  6  6   6

# %% [markdown]
# ## 删

# %%
ps1
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# g    9
# dtype: int64

# %%
# del
del ps1['b']
ps1
# Out:
# a    0
# c    2
# d    3
# e    4
# g    9
# dtype: int64

# %%
pd1
# Out:
#    E  A  B  C   4
# a  7  0  1  2  10
# b  7  3  4  5  11
# c  7  6  7  8  12
# d  0  0  0  0   0

# %%
del pd1['E']
pd1
# Out:
#    A  B  C   4
# a  0  1  2  10
# b  3  4  5  11
# c  6  7  8  12
# d  0  0  0   0

# %%
# drop 删除轴上的数据，返回新的对象， 它不影响原表格数据
# 删除一条数据
ps1.drop('g')
# Out:
# a    0
# c    2
# d    3
# e    4
# dtype: int64

# %%
# 删除多条
ps1.drop(['c', 'd'])
# Out:
# a    0
# e    4
# g    9
# dtype: int64

# %%
# DataFrame
# 删除行
pd1.drop(['a', 'd'])
# Out:
#    A  B  C   4
# b  3  4  5  11
# c  6  7  8  12

# %%
# 指定删除列
pd1.drop(['B'], axis=1)# axis=1是列的删除
# Out:
#    A  C   4
# a  0  2  10
# b  3  5  11
# c  6  8  12
# d  0  0   0

# %%
pd1.drop([4], axis='columns')# 也可以这么写
# Out:
#    A  B  C
# a  0  1  2
# b  3  4  5
# c  6  7  8
# d  0  0  0

# %%
# 注意drop中的 inplace 属性， 当inplace为True时， 可以在原对象上直接进行删除操作，不会返回新的对象
ps1.drop(['g'], inplace=True)
ps1
# Out:
# a    0
# c    2
# d    3
# e    4
# dtype: int64

# %%
pd1.drop([4], axis=1, inplace=True)
pd1
# 这种inplace方法要慎重使用
# Out:
#    A  B  C
# a  0  1  2
# b  3  4  5
# c  6  7  8
# d  0  0  0

# %% [markdown]
# ## 改

# %%
ps1 = pd.Series(np.arange(5), index=['a', 'b', 'c', 'd', 'e'])
print(ps1)
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
pd1 = pd.DataFrame(np.arange(9).reshape(3,3), index=['a', 'b', 'c'], columns=['A', 'B', 'C'])
pd1
# Out:
#    A  B  C
# a  0  1  2
# b  3  4  5
# c  6  7  8

# %%
ps1['a'] = 999 # 根据索引修改
ps1
# Out:
# a    999
# b      1
# c      2
# d      3
# e      4
# dtype: int64

# %%
ps1[0] = 777 # 下标位置修改
ps1
# Out:
# a    777
# b      1
# c      2
# d      3
# e      4
# dtype: int64

# %%
pd1['A'] = [9, 10, 11] # 根据索引修改
pd1
# Out:
#     A  B  C
# a   9  1  2
# b  10  4  5
# c  11  7  8

# %%
pd1.A = 77 # 对象.列
pd1
# Out:
#     A  B  C
# a  77  1  2
# b  77  4  5
# c  77  7  8

# %%
# loc 标签索引
pd1.loc['a'] = 777
pd1
# Out:
#      A    B    C
# a  777  777  777
# b   77    4    5
# c   77    7    8

# %%
# 直接改某一行某一列的数据
pd1.loc['a', "A"] = 999
pd1
# Out:
#      A    B    C
# a  999  777  777
# b   77    4    5
# c   77    7    8

# %% [markdown]
# ## 查

# %%
# Series
ps1
# Out:
# a    777
# b      1
# c      2
# d      3
# e      4
# dtype: int64

# %%
ps1['a']# 标签索引
# Out:
# 777

# %%
ps1[0]# 位置索引
# Out:
# 777

# %%
# 2. 切片索引
print(ps1[1:4])# 位置切片索引 左包括右不包括
print(ps1['b':'e'])# 标签切片索引 左右都包括！！！
# Out:
# b    1
# c    2
# d    3
# dtype: int64
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
# 3. 不连续索引
print(ps1[['b', 'e']])
print(ps1[[0, 2, 3]])
# Out:
# b    1
# e    4
# dtype: int64
# a    777
# c      2
# d      3
# dtype: int64

# %%
# 4. 布尔索引
ps1[ps1>2]
# Out:
# a    777
# d      3
# e      4
# dtype: int64

# %%
# DataFrame
pd1
# Out:
#      A    B    C
# a  999  777  777
# b   77    4    5
# c   77    7    8

# %%
# 1. 列索引
pd1['A']
# Out:
# a    999
# b     77
# c     77
# Name: A, dtype: int64

# %%
# 取多列
pd1[['A', "C"]]
# Out:
#      A    C
# a  999  777
# b   77    5
# c   77    8

# %%
# 选取一个值
pd1['A']['a']
# Out:
# 999

# %%
# 2. 切片索引
pd1[:2] # 获取行
# Out:
#      A    B    C
# a  999  777  777
# b   77    4    5

# %% [markdown]
# # 三. 高级索引
# - loc 标签索引
# - iloc 位置索引
# - ix 标签与位置混合索引

# %%
# 1. loc 标签索引
# loc 是基于标签名的索引，自定义的索引名
ps1['a':'c']
# Out:
# a    777
# b      1
# c      2
# dtype: int64

# %%
ps1.loc['a':'c']# 一般推荐使用高级索引
# Out:
# a    777
# b      1
# c      2
# dtype: int64

# %%
pd1
# Out:
#      A    B    C
# a  999  777  777
# b   77    4    5
# c   77    7    8

# %%
pd1.loc['a':'b', 'A':'C']# 第一个参数是行索引，第二个是列索引
# Out:
#      A    B    C
# a  999  777  777
# b   77    4    5

# %%
# 2. iloc位置索引
pd1.iloc[1:3, 2]
# Out:
# b    5
# c    8
# Name: C, dtype: int64

# %%
# 3. ix 混合索引， 一般不推荐使用
print(pd1.ix['a':'b', 1])
print(pd1.ix[0:2, 'B'])
# Out:
# a    777
# b      4
# Name: B, dtype: int64
# a    777
# b      4
# Name: B, dtype: int64
# /var/sw/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %% [markdown]
# # 索引练习

# %%
import numpy as np
import pandas as pd

# %%
# 准备：读入csv文件
lianjia_df = pd.read_csv(r'lianjia.csv')
print(type(lianjia_df))
lianjia_df.head()# 提取前5行
# Out:
# <class 'pandas.core.frame.DataFrame'>
#   Direction Elevator      Floor     Garden  Id Layout   Price Region  \
# 0        南北      无电梯   低楼层(共6层)        翠竹苑   0   3室1厅   365.0     浦东
# 1         南      有电梯  低楼层(共36层)        百汇园   1   3室2厅  1449.0     徐汇
# 2        南北      有电梯  中楼层(共26层)  仁恒河滨城(二期)   2   3室2厅  1630.0     浦东
# 3         南      有电梯  高楼层(共30层)     财富海景花园   3   3室2厅  2000.0     浦东
# 4         东      有电梯  中楼层(共26层)      仁恒滨江园   4   3室2厅  1360.0     浦东
#
#   Renovation    Size    Year
# 0         简装   77.84  1995.0
# 1         精装   145.2  1995.0
# 2         精装  161.94  1995.0
# 3         精装     185  1995.0
# 4         精装  130.41  1995.0

# %%
# 1. 观察结构，调整列索引顺序
lianjia_df[['Region', 'Garden', 'Layout', 'Floor', 'Id', "Year", 'Size', 'Elevator', 
            'Direction', 'Renovation', 'Price']].head()# 提取前5行
# Out:
#   Region     Garden Layout      Floor  Id    Year    Size Elevator Direction  \
# 0     浦东        翠竹苑   3室1厅   低楼层(共6层)   0  1995.0   77.84      无电梯        南北
# 1     徐汇        百汇园   3室2厅  低楼层(共36层)   1  1995.0   145.2      有电梯         南
# 2     浦东  仁恒河滨城(二期)   3室2厅  中楼层(共26层)   2  1995.0  161.94      有电梯        南北
# 3     浦东     财富海景花园   3室2厅  高楼层(共30层)   3  1995.0     185      有电梯         南
# 4     浦东      仁恒滨江园   3室2厅  中楼层(共26层)   4  1995.0  130.41      有电梯         东
#
#   Renovation   Price
# 0         简装   365.0
# 1         精装  1449.0
# 2         精装  1630.0
# 3         精装  2000.0
# 4         精装  1360.0

# %%
# 2. 增加一列关于目前状况（State，可以使用1代表售出，0代表未售出，注意是随机的！！！）
import random
s = [0, 1]
column_count = lianjia_df.shape[0]# 这里可以计算出Values列的数量（长度）
lianjia_df['State'] = [random.choice(s) for i in range(column_count)]# 这里理解一下，其实就是个for循环对于列的数量
lianjia_df.head()
# Out:
#   Direction Elevator      Floor     Garden  Id Layout   Price Region  \
# 0        南北      无电梯   低楼层(共6层)        翠竹苑   0   3室1厅   365.0     浦东
# 1         南      有电梯  低楼层(共36层)        百汇园   1   3室2厅  1449.0     徐汇
# 2        南北      有电梯  中楼层(共26层)  仁恒河滨城(二期)   2   3室2厅  1630.0     浦东
# 3         南      有电梯  高楼层(共30层)     财富海景花园   3   3室2厅  2000.0     浦东
# 4         东      有电梯  中楼层(共26层)      仁恒滨江园   4   3室2厅  1360.0     浦东
#
#   Renovation    Size    Year  State
# 0         简装   77.84  1995.0      1
# 1         精装   145.2  1995.0      1
# 2         精装  161.94  1995.0      1
# 3         精装     185  1995.0      1
# 4         精装  130.41  1995.0      0

# %%
# 3. 删除Id这一列无用的数据
lianjia_df.drop(['Id'], axis=1, inplace=True)
lianjia_df.head()
# Out:
#   Direction Elevator      Floor     Garden Layout   Price Region Renovation  \
# 0        南北      无电梯   低楼层(共6层)        翠竹苑   3室1厅   365.0     浦东         简装
# 1         南      有电梯  低楼层(共36层)        百汇园   3室2厅  1449.0     徐汇         精装
# 2        南北      有电梯  中楼层(共26层)  仁恒河滨城(二期)   3室2厅  1630.0     浦东         精装
# 3         南      有电梯  高楼层(共30层)     财富海景花园   3室2厅  2000.0     浦东         精装
# 4         东      有电梯  中楼层(共26层)      仁恒滨江园   3室2厅  1360.0     浦东         精装
#
#      Size    Year  State
# 0   77.84  1995.0      1
# 1   145.2  1995.0      1
# 2  161.94  1995.0      1
# 3     185  1995.0      1
# 4  130.41  1995.0      0

# %%
# 4. 查找楼层小于7的所有房屋 (这里是提取低楼层，用的函数)
def extract_low_floor(floors):
    low_floors = []# 列表里对应最低楼层的位置标号是True，其余是False，最后通过此列表里的真假来进行切片
    for floor in floors:
        if "低楼层" in floor:
            low_floors.append(True)
        else:
            low_floors.append(False)
    return low_floors
low_floor_lianjia_df = lianjia_df[extract_low_floor(lianjia_df['Floor'])]
low_floor_lianjia_df.head()
# Out:
#    Direction Elevator      Floor  Garden Layout   Price Region Renovation  \
# 0         南北      无电梯   低楼层(共6层)     翠竹苑   3室1厅   365.0     浦东         简装
# 1          南      有电梯  低楼层(共36层)     百汇园   3室2厅  1449.0     徐汇         精装
# 9         南北      无电梯   低楼层(共6层)     金水苑   3室2厅   240.0     奉贤         简装
# 14         南      有电梯  低楼层(共11层)  万科城花新园   3室2厅   860.0     闵行         精装
# 15         南      有电梯  低楼层(共18层)   鸿凯湾绿苑   3室2厅  1090.0     长宁         简装
#
#       Size    Year  State
# 0    77.84  1995.0      1
# 1    145.2  1995.0      1
# 9   133.62  1995.0      1
# 14  129.73  1995.0      0
# 15  120.76  1995.0      1

# %%
# 5. 修改楼层小于7的房子电梯状态都是无电梯
low_floor_lianjia_df.ix[:, 'Elevator'] = '无电梯'
low_floor_lianjia_df
# Out:
# /var/sw/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#
# /var/sw/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#      Direction Elevator      Floor         Garden Layout   Price Region  \
# 0           南北      无电梯   低楼层(共6层)            翠竹苑   3室1厅   365.0     浦东
# 1            南      无电梯  低楼层(共36层)            百汇园   3室2厅  1449.0     徐汇
# 9           南北      无电梯   低楼层(共6层)            金水苑   3室2厅   240.0     奉贤
# 14           南      无电梯  低楼层(共11层)         万科城花新园   3室2厅   860.0     闵行
# 15           南      无电梯  低楼层(共18层)          鸿凯湾绿苑   3室2厅  1090.0     长宁
# 16           南      无电梯  低楼层(共18层)   荣域飘鹰锦和花园(公寓)   2室2厅   315.0     宝山
# 17           南      无电梯   低楼层(共9层)        恒大华城天地苑   3室2厅   768.0     浦东
# 19           南      无电梯  低楼层(共35层)     浦东世纪花园(公寓)   3室2厅  1400.0     浦东
# 20           南      无电梯  低楼层(共18层)           星颂家园   2室2厅   265.0     浦东
# 21           南      无电梯  低楼层(共11层)       莲浦府邸(公寓)   3室2厅   975.0     闵行
# 26           南      无电梯   低楼层(共6层)           兴浦新村   2室1厅   255.0     杨浦
# 28           南      无电梯  低楼层(共15层)         绿地新江桥城   2室1厅   303.0     嘉定
# 35           南      无电梯   低楼层(共6层)           振宏小区   2室1厅   375.0     闵行
# 38           南      无电梯  低楼层(共13层)     绿城玉兰花园(一期)   3室2厅  1260.0     浦东
# 40           南      无电梯  低楼层(共24层)           嘉瑞花苑   2室2厅   900.0     徐汇
# 43           南      无电梯  低楼层(共30层)  华丽家族汇景天地(商业类)   1室0厅   358.0     黄浦
# 46           南      无电梯  低楼层(共30层)           耀江花园   2室2厅  1300.0     黄浦
# 47           南      无电梯   低楼层(共6层)        打浦路210弄   2室1厅   385.0     黄浦
# 49          南北      无电梯   低楼层(共6层)            广洋苑   3室2厅   670.0     浦东
# 53           南      无电梯   低楼层(共6层)        武定路540弄   2室1厅   450.0     静安
# 55           南      无电梯  低楼层(共11层)         水语人家南苑   1室1厅   175.0     闵行
# 57          南北      无电梯  低楼层(共12层)            香逸湾   3室2厅   350.0     宝山
# 65          南北      无电梯   低楼层(共6层)           金坤花园   3室2厅   650.0     闵行
# 66           南      无电梯  低楼层(共39层)          静安豪景苑   2室2厅  1263.0     静安
# 67           南      无电梯   低楼层(共6层)        东陆新村五街坊   2室1厅   415.0     浦东
# 81           南      无电梯  低楼层(共17层)           中海馨园   3室2厅  1130.0     徐汇
# 82           南      无电梯   低楼层(共6层)           广海花园   2室1厅   355.0     闵行
# 84          南北      无电梯  低楼层(共16层)     绿地海域笙晖(公寓)   3室2厅   345.0     宝山
# 85           南      无电梯  低楼层(共14层)       中环一号(一期)   2室2厅   462.0     宝山
# 86           南      无电梯  低楼层(共19层)          金桥爱建园   3室3厅  1250.0     浦东
# ...        ...      ...        ...            ...    ...     ...    ...
# 1633         南      无电梯   低楼层(共8层)  菊泉新城(陆翔路698弄)   2室1厅   259.0     宝山
# 1634         南      无电梯  低楼层(共28层)           汇豪天下   3室2厅  1288.0     浦东
# 1635         南      无电梯   低楼层(共6层)           金桥新城   2室2厅   490.0     浦东
# 1644         南      无电梯   低楼层(共6层)            华景苑   3室2厅   605.0     浦东
# 1647         南      无电梯   低楼层(共6层)           新闵小区   2室1厅   215.0     闵行
# 1648         南      无电梯   低楼层(共6层)       河间路1077弄   1室1厅   172.0     杨浦
# 1652         南      无电梯  低楼层(共18层)      金地自在城(二期)   3室2厅   430.0     松江
# 1656         南      无电梯   低楼层(共7层)           大桥花苑   1室1厅   235.0     浦东
# 1658         南      无电梯  低楼层(共14层)       名仕豪庭(公寓)   2室2厅   310.0     松江
# 1661         南      无电梯  低楼层(共23层)     香梅花园(三-五期)   1室2厅   680.0     浦东
# 1662        南北      无电梯   低楼层(共6层)   菊泉新城(菊盛路50弄)   2室1厅   275.0     宝山
# 1666        南北      无电梯   低楼层(共6层)           莲浦新苑   3室2厅   698.0     闵行
# 1669         南      无电梯  低楼层(共12层)         三湘世纪花城   3室2厅   830.0     杨浦
# 1670         南      无电梯  低楼层(共17层)          好世鹿鸣苑   1室1厅   465.0     闵行
# 1677        南北      无电梯  低楼层(共16层)      布鲁斯小镇(二期)   2室2厅   255.0     浦东
# 1681         南      无电梯  低楼层(共15层)            虞泽苑   3室2厅   550.0     浦东
# 1683         南      无电梯  低楼层(共26层)         瑞虹新城怡庭   2室2厅  1010.0     虹口
# 1686         南      无电梯  低楼层(共10层)     佳兆业珊瑚湾(公寓)   1室1厅    93.0     奉贤
# 1688         南      无电梯   低楼层(共7层)           华佳花园   2室2厅   405.0     浦东
# 1691         南      无电梯   低楼层(共6层)           宜达新居   1室2厅   210.0     青浦
# 1692         南      无电梯  低楼层(共17层)           浦江宝邸   1室1厅   170.0     闵行
# 1693         南      无电梯   低楼层(共6层)           罗山花苑   2室2厅   695.0     浦东
# 1694         南      无电梯  低楼层(共11层)          万科阳光苑   3室2厅   572.0     闵行
# 1695         南      无电梯   低楼层(共6层)  新世纪花苑(二期)(浦东)   1室1厅   232.0     浦东
# 1697         南      无电梯  低楼层(共30层)         复地新都国际   1室1厅   630.0     闸北
# 1699         南      无电梯  低楼层(共16层)         万邦都市花园   3室2厅   900.0     浦东
# 1700         南      无电梯   低楼层(共6层)           汇成五村   1室1厅   235.0     徐汇
# 1703        南北      无电梯  低楼层(共22层)            徐汇苑   3室2厅  2120.0     徐汇
# 1707        南北      无电梯   低楼层(共6层)           梅陇四村   2室1厅   320.0     徐汇
# 1709         南      无电梯  低楼层(共11层)           华泾绿苑   1室1厅   310.0     徐汇
#
#      Renovation    Size    Year  State
# 0            简装   77.84  1995.0      1
# 1            精装   145.2  1995.0      1
# 9            简装  133.62  1995.0      1
# 14           精装  129.73  1995.0      0
# 15           简装  120.76  1995.0      1
# 16           毛坯    90.5  1995.0      1
# 17           简装  115.67  1995.0      1
# 19           精装  179.52  1995.0      1
# 20           精装   72.64  1995.0      1
# 21           精装  141.21  1995.0      0
# 26           简装   63.98  1995.0      0
# 28           其他   77.42  1995.0      1
# 35           精装      65  1995.0      0
# 38           精装  191.76  1995.0      0
# 40           精装  115.17  1995.0      0
# 43           精装   80.87  1995.0      0
# 46           精装  111.39  1995.0      0
# 47           精装   45.17  1995.0      0
# 49           简装   85.74  1995.0      0
# 53           简装      54  1995.0      0
# 55           精装   56.45  1995.0      1
# 57           精装   89.27  1995.0      1
# 65           精装  134.92  1995.0      0
# 66           精装  115.82  1995.0      1
# 67           毛坯      71  1995.0      1
# 81           简装  144.97  1995.0      1
# 82           精装   67.17  1995.0      1
# 84           简装      94  1995.0      0
# 85           毛坯   97.39  1995.0      1
# 86           精装  171.86  1995.0      0
# ...         ...     ...     ...    ...
# 1633         其他   83.11  1995.0      1
# 1634         精装  149.28  1995.0      0
# 1635         精装    92.2  1995.0      0
# 1644         毛坯  139.41  1995.0      1
# 1647         毛坯    59.9  1995.0      1
# 1648         其他    38.5  1995.0      0
# 1652         毛坯  128.88  1995.0      1
# 1656         简装    44.7  1995.0      0
# 1658         毛坯   89.69  1995.0      0
# 1661         精装   82.01  1995.0      0
# 1662         精装   79.17  1995.0      0
# 1666         精装  135.55  1995.0      0
# 1669         简装  126.15  1995.0      0
# 1670         精装   64.58  1995.0      1
# 1677         毛坯      97  1995.0      0
# 1681         毛坯     116  1995.0      0
# 1683         精装  102.38  1995.0      1
# 1686         精装   50.57  1995.0      1
# 1688         精装   77.36  1995.0      0
# 1691         毛坯   60.63  1995.0      1
# 1692         毛坯   59.99  1995.0      1
# 1693         精装   69.09  1995.0      0
# 1694         其他  139.24  1995.0      1
# 1695         简装   48.13  1995.0      1
# 1697         精装   69.59  1995.0      1
# 1699         简装   127.3  1995.0      1
# 1700         毛坯    36.2  1995.0      1
# 1703         精装     207  1995.0      1
# 1707         其他   64.58  1995.0      0
# 1709         毛坯   64.56  1995.0      0
#
# [579 rows x 11 columns]
