# %% [markdown]
# # Python编程
# ### 从入门到实践（9章）

# %%
# 创建和使用类
# 创建类
class Dog():
    '''模拟一只小狗'''
    def __init__(self, name, age):
        self.name = name
        self.age = age
        
    # 小狗蹲下
    def sit(self):# 上面定义了初始化的函数，那么后面所有的函数(方法属性)必须要有(self)
        print(self.name.title() + ' is now sitting.')
    
    # 小狗打滚
    def roll_over(self):
        print(self.name.title() + ' rolled over!')

# 根据类创建实例
my_dog = Dog('hoho', 8)
print("My dog name is " + my_dog.name.title())
print(my_dog.name.title() + 'is {} years old'.format(my_dog.age))
# 多个实例
ni_dog = Dog('lvlv', 4)
ta_dog = Dog('jiejie', 6)
print()

# 调用方法
my_dog.sit()
my_dog.roll_over()
ni_dog.sit()
ni_dog.roll_over()
ta_dog.sit()
ta_dog.roll_over()
# Out:
# My dog name is Hoho
# Hohois 8 years old
#
# Hoho is now sitting.
# Hoho rolled over!
# Lvlv is now sitting.
# Lvlv rolled over!
# Jiejie is now sitting.
# Jiejie rolled over!

# %%
# 9-1 餐馆
class Restaurant():
    def __init__(self, r_name, r_type):
        self.name = r_name
        self.type = r_type
        
    def describe_r(self):
        print('餐馆的名字是：' + self.name.title())
        print(self.name.title() + '的类型是：' + self.type)
    
    def open_r(self):
        print(self.name + "正在营业中。。。。。。")

restaurant = Restaurant('tianshangrenjian', 'douyou')
print(restaurant.name)
print(restaurant.type)
print()
restaurant.describe_r()
restaurant.open_r()
print()

# 9-2 三家餐馆
r1 = Restaurant('大饼城', '面食')
r2 = Restaurant('喜利来蛋糕店', '蛋糕')
r3 = Restaurant('河北饺子王', '主食')
r1.describe_r()
r2.describe_r()
r3.describe_r()
# Out:
# tianshangrenjian
# douyou
#
# 餐馆的名字是：Tianshangrenjian
# Tianshangrenjian的类型是：douyou
# tianshangrenjian正在营业中。。。。。。
#
# 餐馆的名字是：大饼城
# 大饼城的类型是：面食
# 餐馆的名字是：喜利来蛋糕店
# 喜利来蛋糕店的类型是：蛋糕
# 餐馆的名字是：河北饺子王
# 河北饺子王的类型是：主食

# %%
# 9-3 用户
class User():
    def __init__(self, first_name, last_name, age, sex, addr):
        self.fname = first_name
        self.lname = last_name
        self.age = age
        self.sex = sex
        self.addr = addr
        
    def describe_u(self):
        print('用户的姓名是{} {}'.format(self.fname.title(), self.lname))
        print('用户年龄：' + str(self.age))
        print('用户性别：' + self.sex)
        print('用户地址：' + self.addr)
   
    def greet_u(self):
        print('来自{}的{} {}{}士，见到你很高兴'.format(self.addr,self.fname.title(), self.lname, self.sex))
        
ly = User('liu', 'yang', 28, '男', '北京')
ly.describe_u()
ly.greet_u()
print()
xl = User('xiao', 'liu', 18, '女','武汉')
xl.describe_u()
xl.greet_u()
print()
ll = User('li', 'longji', 26, '男','上海')
ll.describe_u()
ll.greet_u()
# Out:
# 用户的姓名是Liu yang
# 用户年龄：28
# 用户性别：男
# 用户地址：北京
# 来自北京的Liu yang男士，见到你很高兴
#
# 用户的姓名是Xiao liu
# 用户年龄：18
# 用户性别：女
# 用户地址：武汉
# 来自武汉的Xiao liu女士，见到你很高兴
#
# 用户的姓名是Li longji
# 用户年龄：26
# 用户性别：男
# 用户地址：上海
# 来自上海的Li longji男士，见到你很高兴

# %%
# 9-3 用户-1
class User():
    def __init__(self, first_name, last_name, age, sex, addr):
        self.name = first_name.title() + last_name
        self.age = age
        self.sex = sex
        self.addr = addr
        
    def describe_u(self):
        print('用户的姓名是：{}'.format(self.name))
        print('用户年龄：' + str(self.age))
        print('用户性别：' + self.sex)
        print('用户地址：' + self.addr)
   
    def greet_u(self):
        print('欢迎来自{}的{}{}士，见到你很高兴'.format(self.addr,self.name, self.sex))
        
ly = User('liu', 'yang', 28, '男', '北京')
ly.describe_u()
ly.greet_u()
# Out:
# 用户的姓名是：Liuyang
# 用户年龄：28
# 用户性别：男
# 用户地址：北京
# 欢迎来自北京的Liuyang男士，见到你很高兴

# %%
# 使用类和实例
# Car类
class Car():
    
    def __init__(self, make, model, year):
        """初始化描述汽车的属性"""
        self.make = make
        self.model = model
        self.year = year
        
    def get_c_name(self):
        l_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return l_name.title()
    
llr_car = Car('audi', 'a8', 2020)
print(llr_car.get_c_name())
# Out:
# 2020 Audi A8

# %%
# 给属性指定默认值
class Car():
    
    def __init__(self, make, model, year):
        """初始化描述汽车的属性"""
        self.make = make
        self.model = model
        self.year = year
        # 获取汽车的行驶里程, 初始为0, 给了初始值就不需要给形参了，切记
        self.odometer_reading = 0
        
    def get_c_name(self):
        l_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return l_name.title()
    
    # 定义一个方法读取里程
    def read_odomter(self):
        print("This car has " + str(self.odometer_reading) + " miles on it")
        
llr_car = Car('audi', 'a8', 2020)
print(llr_car.get_c_name())
llr_car.read_odomter()
# Out:
# 2020 Audi A8
# This car has 0 miles on it

# %%
# 修改属性的值
# 1. 通过实例直接访问（修改）
class Car():
    
    def __init__(self, make, model, year):
        """初始化描述汽车的属性"""
        self.make = make
        self.model = model
        self.year = year
        # 获取汽车的行驶里程, 初始为0, 给了初始值就不需要给形参了，切记
        self.odometer_reading = 0
        
    def get_c_name(self):
        l_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return l_name.title()
    
    # 定义一个方法读取里程
    def read_odomter(self):
        print("This car has " + str(self.odometer_reading) + " miles on it")
        
llr_car = Car('audi', 'a8', 2020)
print(llr_car.get_c_name())
# 直接通过实例对Car类的属性‘odometer_reading’进行设置
llr_car.odometer_reading = 20
llr_car.read_odomter()
# Out:
# 2020 Audi A8
# This car has 20 miles on it

# %%
# 修改属性的值
# 2. 通过方法修改属性的值
class Car():
    
    def __init__(self, make, model, year):
        """初始化描述汽车的属性"""
        self.make = make
        self.model = model
        self.year = year
        # 获取汽车的行驶里程, 初始为0, 给了初始值就不需要给形参了，切记
        self.odometer_reading = 0
        
    def get_c_name(self):
        l_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return l_name.title()
    
    # 定义一个方法读取里程
    def read_odomter(self):
        print("This car has " + str(self.odometer_reading) + " miles on it")
        
    # 将里程表读数设置为指定的值
    def update_odometer(self, mileage):
        # 判断用户传入的里程是否比原来的大，否则指出不能将里程表回拨
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            ("You can't roll back an odometer!")
            
llr_car = Car('audi', 'a8', 2020)
print(llr_car.get_c_name())
# 此时先调用update_odometer方法获取里程参数，然后再读取里程表
llr_car.update_odometer(20)
llr_car.read_odomter()

# %%
# 修改属性的值
# 3. 通过方法对属性的值进行 递增

class Car():
    def __init__(self, make, model, year):
        """初始化描述汽车的属性"""
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
        
    def get_c_name(self):
        l_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return l_name.title()
    
    # 定义一个方法读取里程
    def read_odometer(self):
        print("This car has " + str(self.odometer_reading) + " miles on it")
        
    # 将里程表读数设置为指定的值
    def update_odometer(self, mileage):
        # 判断用户传入的里程是否比原来的大，否则指出不能将里程表回拨
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            ("You can't roll back an odometer!")
        
    # 将属性值设置为递增特定的量
    def increment_odometer(self, miles):
        # 将里程表读数增加指定的量，增量不能为负值
        if miles >= 0:
            self.odometer_reading += miles
        else:
            print("miles不能为负值")
            
llr_car = Car('audi', 'a8', 2022)
print(llr_car.get_c_name())
# 将里程表读数设置为5000
llr_car.update_odometer(5000)
llr_car.read_odometer()
# 给里程表读数递增200
llr_car.increment_odometer(200)
llr_car.read_odometer()
# Out:
# 2022 Audi A8
# This car has 5000 miles on it
# This car has 5200 miles on it

# %%
# 9-4 就餐人数
class Restaurant():
    def __init__(self, r_name, r_type):
        self.name = r_name
        self.type = r_type
        self.number_served = 0
        
    def describe_r(self):
        print('餐馆的名字是：' + self.name.title())
        print(self.name.title() + '的类型是：' + self.type)
    
    def open_r(self):
        print(self.name + "正在营业中。。。。。。")
    
    def p_r(self):
        print("就餐人数是：" + str(self.number_served))
    
    def set_num_served(self, n):
        self.number_served = n
        
    def increment_num_served(self, l):
        self.number_served += l
        
r = Restaurant('tianshangrenjian', 'douyou')
r.describe_r()
r.open_r()
r.p_r()
r.number_served = 20
r.p_r()
print("*" * 40)


r.set_num_served(60)
r.p_r()
r.increment_num_served(60)
r.p_r()
# Out:
# 餐馆的名字是：Tianshangrenjian
# Tianshangrenjian的类型是：douyou
# tianshangrenjian正在营业中。。。。。。
# 就餐人数是：0
# 就餐人数是：20
# ****************************************
# 就餐人数是：60
# 就餐人数是：120

# %%
# 9-5 尝试登录次数
class User():
    
    def __init__(self, first_name, last_name, age, sex, addr):
        self.fname = first_name
        self.lname = last_name
        self.age = age
        self.sex = sex
        self.addr = addr
        self.login_attempts = 0
        
    def describe_u(self):
        print('用户的姓名是{} {}'.format(self.fname.title(), self.lname))
        print('用户年龄：' + str(self.age))
        print('用户性别：' + self.sex)
        print('用户地址：' + self.addr)
   
    def greet_u(self):
        print('来自{}的{} {}{}士，见到你很高兴'.format(self.addr,self.fname.title(), self.lname, self.sex))
    
    def increment_login_attempts(self):
        self.login_attempts += 1
    
    def reset_login_attempts(self):
        self.login_attempts = 0
        
        
ly = User('liu', 'yang', 28, '男', '北京')
ly.describe_u()
ly.greet_u()
print("* " *30)
ly.increment_login_attempts()
ly.increment_login_attempts()
ly.increment_login_attempts()
ly.increment_login_attempts()
ly.increment_login_attempts()
print(ly.login_attempts)
ly.reset_login_attempts()
print(ly.login_attempts)
# Out:
# 用户的姓名是Liu yang
# 用户年龄：28
# 用户性别：男
# 用户地址：北京
# 来自北京的Liu yang男士，见到你很高兴
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 5
# 0

# %%
# 继承
class Car():
    
    def __init__(self, make, model, year):
        """初始化描述汽车的属性"""
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
        
    def get_c_name(self):
        l_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return l_name.title()
    
    def read_odomter(self):
        print("This car has " + str(self.odometer_reading) + " miles on it")

    def update_odometer(self, mileage):
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            ("You can't roll back an odometer!")
        
    def increment_odometer(self, miles):
        if miles >= 0:
            self.odometer_reading += miles
        else:
            print("miles不能为负值")
            
# 子类电动车
class ElectricCar(Car):
    """电动汽车的独特之处"""
    def __init__(self, make, model, year):
        # super()括号内的子类名和self在Python3中可以省略，Python2中必须有--------
        super(ElectricCar, self).__init__(make, model, year)
        # 另一种方法
        #Car.__init__(self, make, model, year)
        # 给子类定义属性和方法，电动车特有的电瓶容量，初始值设为70--------
        self.batery_size = 70
    
    # 描述电瓶容量方法
    def describe_battery(self):
        print("This electriccar has a " + str(self.batery_size) + '-kwh battery')
        
my_ecar = ElectricCar('tesla', 'model s', 2018)
print(my_ecar.get_c_name())
my_ecar.describe_battery()
# Out:
# 2018 Tesla Model S
# This electriccar has a 70-kwh battery

# %%
# 假设父类中有不符合子类实例的方法，可在子类中重写
class Car():
    
    def __init__(self, make, model, year):
        """初始化描述汽车的属性"""
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
        
    def get_c_name(self):
        l_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return l_name.title()
    
    def read_odomter(self):
        print("This car has " + str(self.odometer_reading) + " miles on it")

    def update_odometer(self, mileage):
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            ("You can't roll back an odometer!")
        
    def increment_odometer(self, miles):
        if miles >= 0:
            self.odometer_reading += miles
        else:
            print("miles不能为负值")
    
    # 这里定义一个名为fill_gas_tank()的方法，而电动车不需要这个方法-------
    def fill_gas_tank(self):
        print("This car has a gas tank")
            
# 子类电动车
class ElectricCar(Car):
    """电动汽车的独特之处"""
    def __init__(self, make, model, year):
        super(ElectricCar, self).__init__(make, model, year)
        self.batery_size = 70

    def describe_battery(self):
        print("This electriccar has a " + str(self.batery_size) + '-kwh battery')
       
    # 电动车不需要描述油箱的方法，这里可以重写一下，这样调用的时候就不会运行父类的方法了------
    def fill_gas_tank(self):# 注意方法名要与父类方法名一致
        print("This electriccar doesn't need a gas tank")
    
my_ecar = ElectricCar('tesla', 'model s', 2018)
print(my_ecar.get_c_name())
my_ecar.fill_gas_tank()
# Out:
# 2018 Tesla Model S
# This electriccar doesn't need a gas tank

# %%
# 将实例用作属性！！！
# Car类
class Car():
    
    def __init__(self, make, model, year):
        """初始化描述汽车的属性"""
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
        
    def get_c_name(self):
        l_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return l_name.title()
    
    def read_odomter(self):
        print("This car has " + str(self.odometer_reading) + " miles on it")

    def update_odometer(self, mileage):
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            ("You can't roll back an odometer!")
        
    def increment_odometer(self, miles):
        if miles >= 0:
            self.odometer_reading += miles
        else:
            print("miles不能为负值")
    
# 定义一个Battery类, 注意它不是Car的子类，也不是ElectricCar的子类，只是一个单独的类
class Battery():
    '''初始化电瓶的属性'''
    def __init__(self, battery_size=70):# 电瓶属性可以不给，默认值是70
        self.battery_size = battery_size
        
    # 再给一个方法打印它------------
    def describe_battery(self):
        print("This electriccar has a " + str(self.battery_size) + '-kwh battery')
         
    # 打印一条消息，指出电瓶的续航里程
    def get_range(self):
        if self.battery_size == 70:
            r = 210
        elif self.battery_size == 80:
            r = 240
        message = "这辆车可以续航" + str(r) + "公里"
        print(message)
        
# ElectricCar类
class ElectricCar(Car):
    """电动汽车的独特之处"""
    def __init__(self, make, model, year):
        super().__init__(make, model, year)
        # 在电动车类中初始化其特有的属性---------
        self.battery = Battery()# 这里直接将类实例Battery()储存到self.battery属性中

my_ecar = ElectricCar('tesla', 'model s', 2018)
print(my_ecar.get_c_name())
# 这里可以调用Battery类中的方法！！！
my_ecar.battery.describe_battery()
my_ecar.battery.get_range()
# Out:
# 2018 Tesla Model S
# This electriccar has a 70-kwh battery
# 这辆车可以续航210公里

# %%
# 9-6 冰激凌小店
class Restaurant():
    def __init__(self, r_name, r_type):
        self.name = r_name
        self.type = r_type
        self.number_served = 0
        
    def describe_r(self):
        print('餐馆的名字是：' + self.name.title())
        print(self.name.title() + '的类型是：' + self.type)
    
    def open_r(self):
        print(self.name + "正在营业中。。。。。。")
    
    def p_r(self):
        print("就餐人数是：" + str(self.number_served))
    
    def set_num_served(self, n):
        self.number_served = n
        
    def increment_num_served(self, l):
        self.number_served += l

# 冰激凌小店是隶属于饭店的一个子类
class IceCreamStand(Restaurant):
    
    def __init__(self, r_name, r_type):
        super().__init__(r_name, r_type)
        # 添加一个用于存储各种口味冰激凌的列表
        self.flavors = []
        
    def icecream_type(self, *ts):
        for t in ts:
            self.flavors.append(t)
        print('我们有包括' + str(self.flavors) + '等口味在内的冰激凌可供选择')
        
i = IceCreamStand('小甜心', '冰激凌')
i.describe_r()
i.open_r()
i.set_num_served(2)
i.p_r()
i.icecream_type('菠萝味','苦咖啡', '草莓加冰')
# Out:
# 餐馆的名字是：小甜心
# 小甜心的类型是：冰激凌
# 小甜心正在营业中。。。。。。
# 就餐人数是：2
# 我们有包括['菠萝味', '苦咖啡', '草莓加冰']等口味在内的冰激凌可供选择

# %%
# 9-7 管理员
class User():
    
    def __init__(self, first_name, last_name, age, sex, addr):
        self.fname = first_name
        self.lname = last_name
        self.age = age
        self.sex = sex
        self.addr = addr
        self.login_attempts = 0
        
    def describe_u(self):
        print('用户的姓名是{} {}'.format(self.fname.title(), self.lname))
        print('用户年龄：' + str(self.age))
        print('用户性别：' + self.sex)
        print('用户地址：' + self.addr)
   
    def greet_u(self):
        print('来自{}的{} {}{}士，见到你很高兴'.format(self.addr,self.fname.title(), self.lname, self.sex))
    
    def increment_login_attempts(self):
        self.login_attempts += 1
        print("访问次数：" + str(self.login_attempts))
        
    def reset_login_attempts(self):
        self.login_attempts = 0
        
class Admin(User):
    
    def __init__(self, first_name, last_name, age, sex, addr):
        super().__init__(first_name, last_name, age, sex, addr)
        self.privileges = ['can add post', 'can delete post', 'can ban user']
        
    def show_privileges(self):
        print('管理员权限为 ' + str(self.privileges))    
    
xl = Admin('小', '龙', 18, '男', '北京')
xl.describe_u()
xl.greet_u()
xl.increment_login_attempts()
xl.increment_login_attempts()
xl.increment_login_attempts()
xl.show_privileges()
xl.reset_login_attempts()
print(xl.login_attempts)
# Out:
# 用户的姓名是小 龙
# 用户年龄：18
# 用户性别：男
# 用户地址：北京
# 来自北京的小 龙男士，见到你很高兴
# 访问次数：1
# 访问次数：2
# 访问次数：3
# 管理员权限为 ['can add post', 'can delete post', 'can ban user']
# 0

# %%
# 9-8 权限
class User():
    
    def __init__(self, first_name, last_name, age, sex, addr):
        self.fname = first_name
        self.lname = last_name
        self.age = age
        self.sex = sex
        self.addr = addr
        self.login_attempts = 0
        
    def describe_u(self):
        print('用户的姓名是{} {}'.format(self.fname.title(), self.lname))
        print('用户年龄：' + str(self.age))
        print('用户性别：' + self.sex)
        print('用户地址：' + self.addr)
   
    def greet_u(self):
        print('来自{}的{} {}{}士，见到你很高兴'.format(self.addr,self.fname.title(), self.lname, self.sex))
    
    def increment_login_attempts(self):
        self.login_attempts += 1
        print("访问次数：" + str(self.login_attempts))
        
    def reset_login_attempts(self):
        self.login_attempts = 0

class Privileges():
    
    def __init__(self):
        self.privileges = ['can add post', 'can delete post', 'can ban user']
        
    def show_privileges(self):
        print('管理员权限为 ' + str(self.privileges))    
    
class Admin(User):
    
    def __init__(self, first_name, last_name, age, sex, addr):
        super().__init__(first_name, last_name, age, sex, addr)
        self.privileges = Privileges()
    

xl = Admin('小', '龙', 18, '男', '北京')
xl.describe_u()
xl.greet_u()
xl.privileges.show_privileges()
# Out:
# 用户的姓名是小 龙
# 用户年龄：18
# 用户性别：男
# 用户地址：北京
# 来自北京的小 龙男士，见到你很高兴
# 管理员权限为 ['can add post', 'can delete post', 'can ban user']

# %%
# 9-9 电瓶升级
class Car():
    
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
        
    def get_c_name(self):
        l_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return l_name.title()
    
    def read_odomter(self):
        print("This car has " + str(self.odometer_reading) + " miles on it")

    def update_odometer(self, mileage):
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            ("You can't roll back an odometer!")
        
    def increment_odometer(self, miles):
        if miles >= 0:
            self.odometer_reading += miles
        else:
            print("miles不能为负值")
    
class Battery():

    def __init__(self, battery_size=70):
        self.battery_size = battery_size
        
    def describe_battery(self):
        print("This electriccar has a " + str(self.battery_size) + '-kwh battery')

    def get_range(self):
        if self.battery_size == 70:
            r = 210
        elif self.battery_size == 85:
            r = 240
        message = "这辆车可以续航" + str(r) + "公里"
        print(message)
        
    def upgrade_battery(self):
        if self.battery_size != 85:
            self.battery_size = 85

class ElectricCar(Car):

    def __init__(self, make, model, year):
        super().__init__(make, model, year)
        self.battery = Battery()
        
t = ElectricCar('audi', 'a12', 2022)
t.battery.get_range()
t.battery.upgrade_battery()
t.battery.get_range()
# Out:
# 这辆车可以续航210公里
# 这辆车可以续航240公里

# %%
# Python标准库， 标准库是一组已经编写好的模块，安装Python的都包含它
# 以下三引号内代码是第4课里的字典示例，现在我们将用模块collections中的一个类————OrderedDict来记录字典的顺序
# 这种方法兼具列表和字典的主要优点(在将信息关联起来的同时保留原来的顺序)
"""
favourite_languages = {
    'jen':"python",
    'liuliu':"c",
    'yangming':'ruby',
    'wudi':'python', 
    }   
for k,v in favourite_languages.items():
    print(k.title() + "'s favouerite language is " + v.title() + ".")
"""
# 首先导入collections模块里的类OrderedDict
from collections import OrderedDict

# 创建一个类实例
favourite_languages = OrderedDict()

# 添加字典并记录顺序
favourite_languages['jen'] = 'python'
favourite_languages['liuliu'] = 'c'
favourite_languages['yangming'] = 'ruby'
favourite_languages['wudi'] = 'python'

# 遍历并打印
for k,v in favourite_languages.items():
    print(k.title() + "'s favouerite language is " + v.title() + ".")
# Out:
# Jen's favouerite language is Python.
# Liuliu's favouerite language is C.
# Yangming's favouerite language is Ruby.
# Wudi's favouerite language is Python.

# %%
# 9-13 使用OrderedDict
from collections import OrderedDict as OD

zidian = OD()
    
zidian["布尔值"] = "结果只能为True或者False"
zidian["lsit"] = "列表，可以进行数值操作的有序集合"
zidian["dict"] = "字典，存储可变的键-值对"
zidian["tuple"] = "元组，一般用于不可更改的数组"
zidian["set"] = "集合，不可重复的无序数组"
zidian["str"] = "字符类型，一般用括号引起来"
zidian["一个'='"] = "赋值，将等号右边的值赋予等号左边"
zidian["遍历"] = "对数组中的每个元素都执行相同的操作"
zidian["嵌套"] = "一系列的字典或列表互相存储，互相循环等的操作"
zidian["and"] = "逻辑与，且，和"

for k,v in zidian.items():
    print(k,"---",v)
# Out:
# 布尔值 --- 结果只能为True或者False
# lsit --- 列表，可以进行数值操作的有序集合
# dict --- 字典，存储可变的键-值对
# tuple --- 元组，一般用于不可更改的数组
# set --- 集合，不可重复的无序数组
# str --- 字符类型，一般用括号引起来
# 一个'=' --- 赋值，将等号右边的值赋予等号左边
# 遍历 --- 对数组中的每个元素都执行相同的操作
# 嵌套 --- 一系列的字典或列表互相存储，互相循环等的操作
# and --- 逻辑与，且，和

# %%
# 9-14 骰子
from random import randint as r

class Die():
    
    def __init__(self,sides=6):
        self.sides = sides
    
    def roll_die(self):
        i = r(1, int(self.sides))
        print(i)

llr = Die()  
for i in range(10):
    llr.roll_die()
print("*" * 30)
# Out:
# 1
# 2
# 4
# 5
# 3
# 6
# 5
# 5
# 2
# 2
# ******************************

# %%
llr10 = Die(10)  
for i in range(10):
    llr10.roll_die()
print("*" * 30)
# Out:
# 10
# 7
# 10
# 8
# 6
# 8
# 7
# 1
# 5
# 4
# ******************************

# %%
llr20 = Die(20)  
for i in range(10):
    llr20.roll_die()
print("*" * 30)
# Out:
# 11
# 7
# 3
# 19
# 3
# 17
# 11
# 8
# 5
# 19
# ******************************
